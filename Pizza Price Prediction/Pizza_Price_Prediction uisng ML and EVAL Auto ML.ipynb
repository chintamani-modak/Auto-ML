# %% [markdown]
# # Project Name : Pizza Price Prediction

# %% [markdown]
# ![pizza-2589575_1920](pizza-2589575_1920.jpg)

# %% [markdown]
# # **Project Background**
#
# - In the current culinary landscape, the vast array of pizza choices, each with its unique combination of toppings and ingredients, presents a significant challenge in predicting pizza prices at the time of order. This variability complicates budget planning for pizza enthusiasts, who lack access to reliable price forecasts that consider historical pricing trends
#
# - This project sets out to address this issue by developing a predictive model for pizza pricing. Our goal is to accurately forecast the price of a pizza based on various factors such as the number of toppings, pizza size, and other relevant parameters.
#
# - To achieve this, we will be employing EvalML, a Python-based, open-source AutoML library. EvalML stands out for its ability to streamline much of the machine learning process, enabling us to efficiently determine the most effective machine learning pipeline for our dataset. This approach will facilitate more accurate and reliable pizza price predictions, benefiting both consumers and vendors in the pizza market.

# %% [markdown]
# # Introduction: Revolutionizing the Approach to Predicting Pizza Prices

# %% [markdown]
# **Introduction**:
#
# Dive into the enigmatic world of pizza price forecasting, a domain where simplicity is overshadowed by intricate challenges and conventional strategies often stumble. In this latest chapter of my 'Pricing & Analytics' series on Medium, we set sail on a captivating expedition into the unpredictable waters of the pizza market, harnessing the innovative prowess of AutoML, with EvalML taking center stage.
#
# **The Challenge**:
#
# Navigating the tumultuous seas of pizza pricing is akin to steering through a tempest, faced with an extensive selection of pizzas, each adorned with a myriad of topping choices, sizes, and more. Here, Artificial Intelligence (AI), and more specifically EvalML, emerges as our beacon, illuminating a path to unprecedented precision and efficiency in price forecasting.
#
# **Introducing EvalML**:
#
# In this narrative, we explore the realms of EvalML, an AutoML solution renowned for its approachability amidst the complexities of machine and deep learning. EvalML serves as a bridge, democratizing the realm of advanced analytics, and revolutionizing our methodology in predicting pizza prices.
#
# **Join the Journey**:
#
# Our exploration transcends mere technological discourse; it's an odyssey where data meets cutting-edge algorithms. I extend an invitation for you to accompany me in demystifying the intricacies of pizza pricing and to witness the transformative influence of EvalML on the landscape of economic analytics.

# %% [markdown]
# # Project Approach

# %% [markdown]
# ![Screenshot 2024-02-01 204110](Screenshot%202024-02-01%20204110.png)

# %% [markdown]
# Our project is structured around core stages essential for a successful machine learning endeavor: Project Scoping, Data Collection and Preprocessing, and Modeling, with a specific focus on pizza price prediction using EvalML.
#
# **Project Scoping Stage**: Here, we'll set clear objectives, identify the key variables that influence pizza prices, and outline our data sources while considering any limitations.
#
# **Data Collection and Preprocessing Stage**: We'll utilize a provided dataset, albeit small, rich in diverse features. This stage is crucial as we clean and preprocess the data, addressing any missing values, outliers, and applying feature engineering to refine our dataset for optimal model performance.
#
# **Modeling Stage**: This involves the application of various machine learning algorithms to train robust predictive models. We're harnessing the power of EvalML, an advanced AutoML tool, to streamline the process of model selection and hyperparameter optimization.
#
# By meticulously covering these phases, our project not only takes a thorough approach to predicting pizza prices but also contributes significantly to the broader understanding of market dynamics in the pizza industry.

# %% [markdown]
# # Methodology: Unveiling the power of EvalML

# %% [markdown]
# Automated Machine Learning (AutoML) stands at the forefront of technological advancement, offering a revolutionary approach to developing high-performance models for predictive tasks. This nnovative process minimizes human intervention, substantially cutting down the time spent on model development and hyperparameter optimization.
#
# In this venture, I've embraced EvalML, a cutting-edge, open-source AutoML library in Python. EvalML is not just a tool; it's a game-changer. It democratizes the world of advanced analytics, transforming our approach to forecasting pizza prices. With EvalML, we can automate significant portions of the machine learning workflow, enabling us to efficiently identify the most effective ML pipeline for our specific dataset. This breakthrough is set to redefine how we understand and predict market trends in the pizza industry

# %% [markdown]
# # Process: Charting the Course

# %% [markdown]
# Embarking on this Jupyter Notebook odyssey has been both enlightening and demanding:
# - **Define the Project**: Our first step is to dive deep into the heart of the business conundrum, setting the stage for our analytical narrative.
# - **Data Collection & Understanding**: This phase is akin to gathering the pieces of a vast puzzle, each piece holding secrets to the bigger picture. We meticulously collect and decode the dataset's complexities, laying the groundwork for our insights.
# - **Data Preprocessing**: Here lies the foundation of our analytical edifice - a meticulous process of cleansing and structuring data, making it comprehensible for our machine learning algorithms. It's a critical step where data is transformed into a language that machines understand.
# - **Feature Engineering & Selection**: In this crucial phase, we act as the alchemists of data science, identifying and crafting the most potent attributes that will fuel our predictive model. It's a quest to find the golden features that will unlock the predictive power of our model.
# - **Model Selection**: At this juncture, EvalML takes the helm, embarking on a quest through the algorithmic wilderness to unearth the champion model. It's a sophisticated process where EvalML evaluates countless contenders in its quest for the optimal solution.
# - **Evaluation**: The journey doesn't end with the discovery of our model; it's only the beginning. We put our chosen champion through a gauntlet of tests, scrutinizing its performance across various metrics like accuracy, precision, recall, and more. It's a rigorous examination to ensure our model doesn't just survive but thrives in the real world.
#
# This journey through the Jupyter Notebook has been a testament to the power of EvalML and the transformative potential of AutoML in the realm of predictive analytics. It's a narrative of how technology can empower us to unravel complex problems with elegance and efficiency.

# %% [markdown]
# ## Step 1: Import Libraries and Read Dataset

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
# ### Reading the DataSet

# %%
df= pd.read_csv("pizza_v2.csv")

# %%
df.head()
# Out:
#   company price_rupiah diameter  ... extra_sauce extra_cheese extra_mushrooms
# 0       A    Rp235,000  22 inch  ...         yes          yes              no
# 1       A    Rp198,000  20 inch  ...         yes          yes              no
# 2       A    Rp120,000  16 inch  ...         yes          yes             yes
# 3       A    Rp155,000  14 inch  ...         yes           no             yes
# 4       A    Rp248,000  18 inch  ...         yes           no             yes
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Step 2: Data Analysis

# %%
df.isnull().sum()
# Out:
# company            0
# price_rupiah       0
# diameter           0
# topping            0
# variant            0
# size               0
# extra_sauce        0
# extra_cheese       0
# extra_mushrooms    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   company          129 non-null    object
#  1   price_rupiah     129 non-null    object
#  2   diameter         129 non-null    object
#  3   topping          129 non-null    object
#  4   variant          129 non-null    object
#  5   size             129 non-null    object
#  6   extra_sauce      129 non-null    object
#  7   extra_cheese     129 non-null    object
#  8   extra_mushrooms  129 non-null    object
# dtypes: object(9)
# memory usage: 9.2+ KB

# %%
df.columns
# Out:
# Index(['company', 'price_rupiah', 'diameter', 'topping', 'variant', 'size',
#        'extra_sauce', 'extra_cheese', 'extra_mushrooms'],
#       dtype='object')

# %%
# Renaming the price column
df.rename({'price_rupiah':'price'}, axis=1, inplace=True)

# Extracting digits in price column and converting to integer
df.price = df.price.str.replace('Rp','').str.replace(',','').astype(int)

# Extracting digits in diameter and converting to integer
df['diameter'] = df['diameter'].str.extract('(\d+\.?\d*)').astype(float)

# %%
df.head()
# Out:
#   company   price  diameter  ... extra_sauce extra_cheese extra_mushrooms
# 0       A  235000      22.0  ...         yes          yes              no
# 1       A  198000      20.0  ...         yes          yes              no
# 2       A  120000      16.0  ...         yes          yes             yes
# 3       A  155000      14.0  ...         yes           no             yes
# 4       A  248000      18.0  ...         yes           no             yes
#
# [5 rows x 9 columns]

# %%
sns.histplot(data=df, x="company",hue='extra_sauce')
# Out:
# <AxesSubplot: xlabel='company', ylabel='Count'>

# %% [markdown]
# In the company C maximum number of people have taken the extra courses.

# %%
df_company=df.groupby('company').agg({'company':['count']})
sns.kdeplot(df['company'].value_counts(), color='g', shade=True)
# Out:
# <AxesSubplot: xlabel='company', ylabel='Density'>

# %% [markdown]
# the 15 to 35 is the price range with maximum number of price is distributed around 25

# %%
df_company=df.groupby('topping').agg({'topping':['count']})
sns.kdeplot(df['topping'].value_counts(), color='r', shade=True)
# Out:
# <AxesSubplot: xlabel='topping', ylabel='Density'>

# %%
sns.histplot(data=df, x="company",hue='extra_cheese')
# Out:
# <AxesSubplot: xlabel='company', ylabel='Count'>

# %% [markdown]
# People preferred the extra cheese mechanism and which which were required the highest price.

# %%
sns.histplot(data=df, x="company",hue='extra_sauce')
# Out:
# <AxesSubplot: xlabel='company', ylabel='Count'>

# %% [markdown]
# People preferred the extra sauce mechanism and which which were required the highest price.

# %%
sns.histplot(data=df, x='price',bins=30)
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %%
# Pizza Diameter vs mean Price
sns.pointplot(data=df.sort_values(by='diameter'),
              x='diameter', y='price')
plt.xticks(rotation=90);

# %% [markdown]
# Higehr the diamter, higher the price it commands with highest price at 250000 with 18 diameter pizza

# %%
plt.figure(figsize=(13,3))
sns.boxplot(data=df, x='variant', y='price')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From the above we can see that the double signature pizza is the costliest among different types of pizza included in the dataset

# %%
plt.figure(figsize=(10,3))
sns.boxplot(data=df, x='topping', y='price')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From the above we can see that the pepperoni topping is the costliest among different types of toppings included in the dataset

# %% [markdown]
# ## Step 3: Feature Engineering

# %% [markdown]
# #### One Hot Encoding

# %%
from sklearn.preprocessing import LabelEncoder
import category_encoders as ce
def one_hot_encoding(df,col):
    one_hot_encoder=ce.OneHotEncoder(cols=col,return_df=True,use_cat_names=True)
    df_final = one_hot_encoder.fit_transform(df)
    return df_final
def one_hot(df, column):
    df = one_hot_encoding(df,column)
    return df

# %%
df = one_hot(df, 'company')
df = one_hot(df, 'topping')
df = one_hot(df, 'variant')
df = one_hot(df, 'size')
df = one_hot(df, 'extra_sauce')
df = one_hot(df, 'extra_cheese')

# %%
df = one_hot(df, 'extra_mushrooms')

# %%
df.head()
# Out:
#    company_A  company_B  ...  extra_mushrooms_no  extra_mushrooms_yes
# 0          1          0  ...                   1                    0
# 1          1          0  ...                   1                    0
# 2          1          0  ...                   0                    1
# 3          1          0  ...                   0                    1
# 4          1          0  ...                   0                    1
#
# [5 rows x 51 columns]

# %%
df.dtypes
# Out:
# company_A                      int64
# company_B                      int64
# company_C                      int64
# company_D                      int64
# company_E                      int64
# price                          int64
# diameter                     float64
# topping_chicken                int64
# topping_papperoni              int64
# topping_mushrooms              int64
# topping_smoked_beef            int64
# topping_mozzarella             int64
# topping_black_papper           int64
# topping_tuna                   int64
# topping_meat                   int64
# topping_sausage                int64
# topping_onion                  int64
# topping_vegetables             int64
# topping_beef                   int64
# variant_double_signature       int64
# variant_american_favorite      int64
# variant_super_supreme          int64
# variant_meat_lovers            int64
# variant_double_mix             int64
# variant_classic                int64
# ...

# %%
x = df.drop("price",axis = 1)
y = df["price"]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size = 0.2)

# %% [markdown]
# # Step 4:  Model Building using Traditional ML Algorithms

# %% [markdown]
# ### We will be using the following models:-
# - XGB Regressor
# - Support Vector Regressor

# %% [markdown]
# ## XGB Regressor

# %% [markdown]
# ### We will use Grid Search CV for finding the best parameters

# %%
from xgboost import XGBRegressor

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid= {'n_estimators':[2000,4000,6000],
             'max_depth':[3,4,5,6],
             'learning_rate':[0.01,0.1,0.2,0.3,0.5]
}

# %%
final = GridSearchCV(XGBRegressor(random_state=42),
                                    param_grid=param_grid,
                                    scoring='r2')

# %%
X_train.head()
# Out:
#      company_A  company_B  ...  extra_mushrooms_no  extra_mushrooms_yes
# 112          0          0  ...                   0                    1
# 31           0          1  ...                   0                    1
# 94           0          0  ...                   1                    0
# 37           0          1  ...                   0                    1
# 43           0          1  ...                   1                    0
#
# [5 rows x 50 columns]

# %%
final.fit(X_train,Y_train)
# Out:
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bi...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
# ...

# %%
final.best_params_
# Out:
# {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 6000}

# %%
Best_param= {'learning_rate': 0.2, 'max_depth': 6, 'n_estimators': 2000}

# %%
xgb= XGBRegressor(learning_rate= 0.2,max_depth= 6, n_estimators= 2000)

# %%
xgb.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
pred= xgb.predict(X_test)

# %%
from sklearn import metrics

# %%
from sklearn import metrics

mae = metrics.mean_absolute_error(pred, Y_test)
print(f'MAE: {mae:.5f}')

rsme = metrics.mean_squared_error(pred, Y_test, squared=False)
print(f'RMSE: {rsme:.5f}')

r2_score = metrics.r2_score(pred, Y_test)
print(f'r2 score: {r2_score:.5f}')
# Out:
# MAE: 3017.41632
# RMSE: 6589.12116
# r2 score: 0.96035

# %% [markdown]
# High Predictive Power: With an R² score of 0.94708, your model explains about 94.7% of the variance, indicating it is quite effective in capturing the overall trend in the data.
#
# Significant Prediction Errors: Despite the high R², the MAE (4740.21965) and RMSE (11509.70057) suggest that the model's individual predictions can vary considerably from the actual values, indicating a notable degree of error.
#
# Possible Impact of Outliers: The larger RMSE compared to MAE suggests the presence of outliers or a few large errors, which may be skewing the predictions.
#
# Model Suitability Depends on Application: The model is good for understanding general trends but may be less reliable for precise predictions for each data point.
#
# Potential for Improvement: There may be a need to investigate and potentially improve the model, possibly by addressing overfitting, re-evaluating feature selection, or exploring different modeling techniques.

# %% [markdown]
# ## SVR

# %%
from sklearn.svm import SVR

# %%
svr= SVR()

# %%
svr.fit(X_train,Y_train)
# Out:
# SVR()

# %%
pred1= svr.predict(X_test)

# %%
mae = metrics.mean_absolute_error(pred1, Y_test)
print(f'MAE: {mae:.5f}')

rsme = metrics.mean_squared_error(pred1, Y_test, squared=False)
print(f'RMSE: {rsme:.5f}')

r2_score = metrics.r2_score(pred1, Y_test)
print(f'r2 score: {r2_score:.5f}')
# Out:
# MAE: 26265.36670
# RMSE: 33381.37754
# r2 score: -35719810.03513

# %% [markdown]
# Very High Errors: The extremely high MAE and RMSE values suggest that the model's predictions are, on average, far from the actual values.
#
# Ineffective Model: The highly negative R² score indicates that the model is performing much worse than a simple average. This is a clear sign of a model that fails to capture any meaningful patterns in the data.
#
# These metrics suggest fundamental problems with the model, possibly due to inappropriate model choice, poor feature selection, data quality issues, or incorrect data processing. It's crucial to thoroughly review and likely revise the model and the data it's based on.

# %% [markdown]
# # Step 5:  Model Building using cutting edge AutoML

# %% [markdown]
# ![Evalml](Evalml.png)

# %% [markdown]
# ### EvalML is an open-source AutoML library written in python that automates a large part of the machine learning process and we can easily evaluate which machine learning pipeline works better for the given set of data.

# %% [markdown]
# ### Installing Eval ML

# %%
# !pip install evalml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %% [markdown]
# ### We will use the same train and test dataset for this

# %%
import evalml

# %%
evalml.problem_types.ProblemTypes.all_problem_types
# Out:
# [<ProblemTypes.BINARY: 'binary'>,
#  <ProblemTypes.MULTICLASS: 'multiclass'>,
#  <ProblemTypes.REGRESSION: 'regression'>,
#  <ProblemTypes.TIME_SERIES_REGRESSION: 'time series regression'>,
#  <ProblemTypes.TIME_SERIES_BINARY: 'time series binary'>,
#  <ProblemTypes.TIME_SERIES_MULTICLASS: 'time series multiclass'>,
#  <ProblemTypes.MULTISERIES_TIME_SERIES_REGRESSION: 'multiseries time series regression'>]

# %%
X_train, X_test, y_train, y_test = evalml.preprocessing.split_data(x, y, problem_type='regression')

# %% [markdown]
# **Running the Auto ML to select best Algorithm**

# %%
from evalml.automl import AutoMLSearch
automl = AutoMLSearch(X_train=X_train, y_train=y_train, problem_type='regression')
automl.search()
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000049 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20
# [LightGBM] [Info] Number of data points in the train set: 68, number of used features: 7
# [LightGBM] [Info] Start training from score 90286.764706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
automl.rankings
# Out:
#    id  ...                                         parameters
# 0   3  ...  {'Imputer': {'categorical_impute_strategy': 'm...
# 1   2  ...  {'Imputer': {'categorical_impute_strategy': 'm...
# 2   1  ...  {'Imputer': {'categorical_impute_strategy': 'm...
# 3   5  ...  {'Imputer': {'categorical_impute_strategy': 'm...
# 4   4  ...  {'Imputer': {'categorical_impute_strategy': 'm...
# 5   0  ...       {'Baseline Regressor': {'strategy': 'mean'}}
#
# [6 rows x 9 columns]

# %%
automl.best_pipeline
# Out:
# pipeline = RegressionPipeline(component_graph={'Imputer': ['Imputer', 'X', 'y'], 'Select Columns Transformer': ['Select Columns Transformer', 'Imputer.x', 'y'], 'XGBoost Regressor': ['XGBoost Regressor', 'Select Columns Transformer.x', 'y']}, parameters={'Imputer':{'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'boolean_impute_strategy': 'most_frequent', 'categorical_fill_value': None, 'numeric_fill_value': None, 'boolean_fill_value': None}, 'Select Columns Transformer':{'columns': ['company_A', 'company_B', 'company_C', 'diameter', 'topping_chicken', 'topping_papperoni', 'topping_mushrooms', 'topping_smoked_beef', 'topping_mozzarella', 'topping_black_papper', 'variant_double_signature', 'variant_double_mix', 'variant_classic', 'variant_double_decker', 'variant_BBQ_meat_fiesta', 'size_jumbo', 'size_reguler', 'size_small', 'size_medium', 'size_XL', 'extra_sauce_yes', 'extra_sauce_no', 'extra_cheese_yes', 'extra_cheese_no', 'extra_mushrooms_no']}, 'X
# ...

# %%
best_pipeline=automl.best_pipeline

# %%
automl.describe_pipeline(automl.rankings.iloc[0]["id"])
# Out:
# *************************************************************
# * XGBoost Regressor w/ Imputer + Select Columns Transformer *
# *************************************************************
#
# Problem Type: regression
# Model Family: XGBoost
#
# Pipeline Steps
# ...
# 1. Imputer
# 	 * categorical_impute_strategy : most_frequent
# 	 * numeric_impute_strategy : mean
# 	 * boolean_impute_strategy : most_frequent
# 	 * categorical_fill_value : None
# 	 * numeric_fill_value : None
# 	 * boolean_fill_value : None
# 2. Select Columns Transformer
# ...

# %%
best_pipeline.score(X_test, y_test, objectives=["R2"])
# Out:
# OrderedDict([('R2', 0.968590569595417)])

# %% [markdown]
# The provided metric is an R² score of 0.968590569595417. Here's a concise conclusion based on this score:
#
# Highly Effective Model: An R² score of approximately 0.969 indicates that the model is highly effective in explaining the variance in the dependent variable. This suggests that about 96.9% of the variance in the target variable can be predicted from the independent variables.
#
# Strong Predictive Power: Such a high R² value typically reflects a strong predictive power of the model, assuming that the R² score is not a result of overfitting.
#
# However, while the R² score is an important indicator of model performance, it should not be the sole metric for evaluating a model's effectiveness. It's also essential to consider other metrics like MAE, RMSE, and to check for overfitting, to get a comprehensive view of the model's performance.

# %% [markdown]
# ### Making a model based on R2 objective

# %%
automl_r2 = AutoMLSearch(X_train=X_train, y_train=y_train,
                          problem_type='regression',
                          objective='R2',
                          
                          max_batches=1,
                          optimize_thresholds=True)

automl_r2.search()
# Out:
# {1: {'Random Forest Regressor w/ Imputer + RF Regressor Select From Model': 1.4990801811218262,
#   'Total time of batch': 1.6208045482635498}}

# %%
automl_r2.rankings
# Out:
#    id  ...                                         parameters
# 0   1  ...  {'Imputer': {'categorical_impute_strategy': 'm...
# 1   0  ...       {'Baseline Regressor': {'strategy': 'mean'}}
#
# [2 rows x 9 columns]

# %% [markdown]
# From the above, it seems that Random forest regressor is the best performing model with high R2 score theteby keeping high accuracy levels

# %%
automl_r2.describe_pipeline(automl_r2.rankings.iloc[0]["id"])
# Out:
# ***********************************************************************
# * Random Forest Regressor w/ Imputer + RF Regressor Select From Model *
# ***********************************************************************
#
# Problem Type: regression
# Model Family: Random Forest
#
# Pipeline Steps
# ...
# 1. Imputer
# 	 * categorical_impute_strategy : most_frequent
# 	 * numeric_impute_strategy : mean
# 	 * boolean_impute_strategy : most_frequent
# 	 * categorical_fill_value : None
# 	 * numeric_fill_value : None
# 	 * boolean_fill_value : None
# 2. RF Regressor Select From Model
# 	 * number_features : None
# 	 * n_estimators : 10
# 	 * max_depth : None
# 	 * percent_features : 0.5
# 	 * threshold : median
# 	 * n_jobs : -1
# 3. Random Forest Regressor
# 	 * n_estimators : 100
# 	 * max_depth : 6
# 	 * n_jobs : -1
#
# Training
# ...
# Training for regression problems.
# Total training time (including CV): 1.5 seconds
#
# Cross Validation
# ----------------
# ...

# %%
best_pipeline_r2 = automl_r2.best_pipeline

# %%
best_pipeline_r2.score(X_test, Y_test,  objectives=["R2"])
# Out:
# OrderedDict([('R2', -0.2429850532288833)])

# %% [markdown]
# #### Save the model

# %%
best_pipeline.save("model.pkl")

# %% [markdown]
# #### Load our model

# %%
final_model=automl.load('model.pkl')

# %% [markdown]
# #### Final Predictions

# %%
final_model.predict(X_test)
# Out:
# 40      72471.976562
# 24     149389.234375
# 107     69969.906250
# 51      95690.078125
# 8       91553.375000
# 122     83624.851562
# 44      46333.968750
# 104     83624.851562
# 73      33897.734375
# 7       73518.554688
# 60      94736.921875
# 10     138360.843750
# 90      46850.273438
# 97      89828.445312
# 30      97586.210938
# 33      92487.539062
# 2      137392.343750
# 59      62584.785156
# 50      62725.000000
# 26      49420.140625
# 22     113930.000000
# 109     74064.187500
# 48      94756.085938
# 68      65887.226562
# 92      50783.730469
# 124     37175.656250
# Name: price, dtype: float64
